# %%
import glob as g
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import os
from matplotlib import font_manager as fm, rcParams

# %%
#extraction
def extract_from_csv(file):
    df = pd.read_csv(file,sep=';')
    return df


def extract_data(path):
    extracted_data = pd.DataFrame()
    files_csv = g.glob(path,recursive = True)
    for i in files_csv:
        extracted_data = extracted_data.append(extract_from_csv(i),ignore_index = True)
    
        #print( extracted_data.head())
        
    return extracted_data


def Num_et(data):
    Num_etu= data['1. Quel est votre numéro étudiant ? (ex: e22XXXX)']
    for i in Num_etu.index:
        Num = Num_etu[i]
        if(Num[0].isdigit()):
            Num = 'e' + Num[2:]
        Num_etu[i]= Num
    data['1. Quel est votre numéro étudiant ? (ex: e22XXXX)'] = Num_etu
    #print(data['1. Quel est votre numéro étudiant ? (ex: e22XXXX)'])
    return data

#rename columns
column_mapping = {'4. Quel est votre degré d\'intérêt pour ces technologies ? (0 → aucun intérêt, 5 → passionné)   [Web (HTML, CSS , PHP , CMS)]':'4.Web',
                             '4. Quel est votre degré d\'intérêt pour ces technologies ? (0 → aucun intérêt, 5 → passionné)   [Cloud (Azure, AWS,GCP)]':'4.Cloud',
                             '4. Quel est votre degré d\'intérêt pour ces technologies ? (0 → aucun intérêt, 5 → passionné)   [Embarqué (Arduino, Assembleur, Raspberry...)]':'4.Embarqué',
                             '4. Quel est votre degré d\'intérêt pour ces technologies ? (0 → aucun intérêt, 5 → passionné)   [Mobile (Android, iOS,Cross-platform) ]':'4.Mobile',
                             '4. Quel est votre degré d\'intérêt pour ces technologies ? (0 → aucun intérêt, 5 → passionné)   [Dev Jeux vidéo (Unity, Unreal Engine)]':'4.Dev'}
                             

def rename_columns(data, column_mapping):
    data = data.rename(columns=column_mapping)
    return data
    
def transform_data(data):
    data=Num_et(data)
    data = rename_columns(data, column_mapping)
    #print(data)
    return data


    
#Load data
def load(targetfile, data_to_load):
    data_to_load.to_csv(targetfile)
    
#execution of ETL (Data pipeline)
path = "/Users/harolddesirebonchouo/Desktop/Astre:Ips/data/data.csv"
def ETL(path):
    extract_df = extract_data(path)
    transform_df = transform_data(data = extract_df)
    transform_df = transform_df.fillna(0)
    load_df = load(targetfile ="transformdata1.csv", data_to_load=transform_df)
    return transform_df

New_df = ETL(path)
# Out:
# /var/folders/m4/qv4gvwhx4b53q0s32fn0lr0w0000gn/T/ipykernel_76924/2265563908.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Num_etu[i]= Num

# %%
New_df= New_df.assign(Notes=0)

def switch_example(case):
    if case == 'Ne connais pas':
         note = -1
    elif case == 'Jamais':
        note = 0
    elif case == 'Un peu':
        note = 1
    elif case == 'Régulièrement':
        note = 2
    elif case == 'Tout le temps':
        note = 3
    elif case == 'J\'y suis ':
        note = 2
    elif case == 'Interessé':
        note = 2
    elif case == 'Pas intéressé':
        note = 0
    elif case == 'Prépa intégré':
        note = -1
    elif case == 'CPGE ATS':
        note = 1
    elif case == 'CPGE PT':
        note = 1
    elif case == 'CPGE TSi':
        note = 1
    elif case == 'CPGE MP':
        note = 1
    elif case == 'CPGE MP2I/MPSI':
        note = 1
    elif case == 'CPGE BL':
        note = 1
    elif case == 'CPGE PC':
        note = 1
    elif case == 'BTS SIO':
        note = -1
    elif case == 'BTS SN':
        note = -1
    elif case == 'DUT Informatique':
        note = -1
    elif case == 'DUT Métiers du Multimédia et Internet':
        note = -1
    elif case == 'L2, L3 informatique':
        note = -1
    elif case == 'M1, M2 informatique':
        note = -1
    elif case == 'Windows':
        note = -1
    elif case == 'MacOS':
        note = -1
    elif case == 'Distribution Linux (Ubuntu, Debian, Arch...)':
        note = 1
    elif case == 'C’est un professionnel expert dans un domaine technique capable de résoudre des problèmes de haut niveau et innovants.':
        note = 1
    elif case == 'Un ingénieur est un Homme capable de prendre du recul et d’avoir une solide culture générale, technique et humaine.':
        note = -1
    elif case == 'C’est avant tout un cadre supérieur technique qui a pour mission de piloter un projet et de gérer une ou plusieurs équipes en interface avec le client.':
        note = 1
    else:
        note = 0
    return note
        
for index, row in New_df.iterrows():
    if(row['2. Quelle est la définition d’un ingénieur qui vous correspond le mieux ?']): 
        valuer = New_df.at[index, '2. Quelle est la définition d’un ingénieur qui vous correspond le mieux ?']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer) 
    
    if(row['3. Êtes-vous plutôt programmation ... [Procédurale]']):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + row['3. Êtes-vous plutôt programmation ... [Procédurale]']   
    if(row['3. Êtes-vous plutôt programmation ... [Orienté Object]']):   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - row['3. Êtes-vous plutôt programmation ... [Orienté Object]'] 
    if(row['3. Êtes-vous plutôt programmation ... [Fonctionnelle]']):   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + row['3. Êtes-vous plutôt programmation ... [Fonctionnelle]'] 
    if(row['4.Web']):   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - row['4.Web']
    if(row['4.Cloud']):   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + row['4.Cloud']
    if(row['4.Embarqué']):   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + row['4.Embarqué']
    if(row['4.Mobile']):   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - row['4.Mobile']
    if(row['4.Dev']):   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - row['4.Dev']
    if(row['5. Quelle(s) matière(s) avez-vous aimé particulièrement au lycée parmi les suivantes : ']): 
        liste_matiere = New_df.at[index, '5. Quelle(s) matière(s) avez-vous aimé particulièrement au lycée parmi les suivantes : '].split(",")
        for matiere in liste_matiere:
            if(matiere == 'Maths'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            elif(matiere == 'Physique/Chimie'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            elif(matiere == 'Littérature/Philosophie'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Histoire/Géographie'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Sciences de gestion'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Arts Plastiques/Arts appliqués'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Sciences de l\'ingénieur'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            else:
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
    if(row['6. Quel(s) cours avez-vous aimé particulièrement au semestre S5 ?']): 
        ligne6 = row['6. Quel(s) cours avez-vous aimé particulièrement au semestre S5 ?'] 
        if(ligne6 == "Cryptographie (en Maths)"):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
        elif(ligne6 == 'Physique'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
        elif(ligne6 == 'Anglais'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
        elif(ligne6 == 'Conduite de projet'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
        elif(ligne6 == 'Droit du travail'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
        elif(ligne6 == 'Electronique'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
        elif(ligne6 == 'Programmation informatique'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
        elif(ligne6 == 'Technologie de l’internet'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
        elif(ligne6 == 'Algorithmique'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
        elif(ligne6 == 'Architecture des ordinateurs'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
        elif(ligne6 == 'Logique combinatoire et séquentielle'):
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
        else:
            New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [LabView]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [LabView]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer) 
        
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Excel]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Excel]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - switch_example(valuer) 
    
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Blender]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Blender]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - switch_example(valuer)
    
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Unity]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Unity]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - switch_example(valuer)
        
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Figma]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Figma]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - switch_example(valuer)
        
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Cisco Packet Tracer]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [Cisco Packet Tracer]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer)
        
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [SolidWorks]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [SolidWorks]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer)
        
    if(row['7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [AutoCAD]']): 
        valuer = New_df.at[index, '7. Quels logiciels / applications avez-vous l’habitude (ou avez-vous déjà utilisé) d’utiliser ?  [AutoCAD]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer)
    
    if(row['8. Parmi ces machines, lesquelles espérez-vous pouvoir utiliser au cours de vos projets d’année ? ']): 
        liste_matiere = New_df.at[index, '8. Parmi ces machines, lesquelles espérez-vous pouvoir utiliser au cours de vos projets d’année ? '].split(",")
        for matiere in liste_matiere:
            if(matiere == 'Imprimante 3D'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            elif(matiere == 'Drone'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            elif(matiere == 'Casque VR'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Cartes électroniques programmables (Arduino, Raspberry...)'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Oscilloscope'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Casque neuronal'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            elif(matiere == 'Smartphones'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            else:
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
                
    if(row['9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [K[art]el]']): 
        valuer = New_df.at[index, '9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [K[art]el]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - switch_example(valuer) 
    
    if(row['9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Ensimersion]']): 
        valuer = New_df.at[index, '9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Ensimersion]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - switch_example(valuer)
        
    if(row['9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Ensim’elec]']): 
        valuer = New_df.at[index, '9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Ensim’elec]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer)
    
    if(row['9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Enigma]']): 
        valuer = New_df.at[index, '9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Enigma]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer)
    
    if(row['9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [L\'Ensimien]']): 
        valuer = New_df.at[index, '9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [L\'Ensimien]']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - switch_example(valuer)
      
    if(row['10. Si on vous donne une imprimante 3D, qu\'est-ce que vous imprimez d’abord ?'] == 'Statue de Mario'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - 1
        
    if(row['10. Si on vous donne une imprimante 3D, qu\'est-ce que vous imprimez d’abord ?'] == 'Boitier pour sa carte arduino'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + 1
        
    if(row['10. Si on vous donne une imprimante 3D, qu\'est-ce que vous imprimez d’abord ?'] == 'Des boutons'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + 1
        
    if(row['10. Si on vous donne une imprimante 3D, qu\'est-ce que vous imprimez d’abord ?'] == 'Une coque de téléphone'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - 1
        
    
    if(row['11. Quels sont vos hobbies ?']): 
        liste_matiere = New_df.at[index, '11. Quels sont vos hobbies ?'].split(",")
        for matiere in liste_matiere:
            if(matiere == 'Lecture'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Bricolage'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            elif(matiere == 'Sport'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            elif(matiere == 'Art Dessin'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Jeux vidéos'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Musique'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
            elif(matiere == 'Musculation'):
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
            else:
                New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1
                
    if(row['12. Utilisez-vous des sites pour créer une palette de couleurs ?'] == 'oui'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']-1
    else :   
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes']+1

    if(row['13. Votre ordinateur tombe en panne, que faites vous ?'] == 'Vous le démontez pour comprendre d\'où vient le problème'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + 1
    if(row['13. Votre ordinateur tombe en panne, que faites vous ?'] == 'Vous essayez de le réparer en passant par le BIOS'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + 1
    if(row['13. Votre ordinateur tombe en panne, que faites vous ?'] == 'Vous allez voir un réparateur'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - 1
    if(row['13. Votre ordinateur tombe en panne, que faites vous ?'] == 'Vous en rachetez un'):
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] - 1 
    
    if(row['14. Qu’avez-vous fait avant le cycle ingénieur ?']): 
        valuer = New_df.at[index, '14. Qu’avez-vous fait avant le cycle ingénieur ?']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer) 
        
    if(row['15. Quel est ton système d’exploitation que tu utilises le plus pour développer ?']): 
        valuer = New_df.at[index, '15. Quel est ton système d’exploitation que tu utilises le plus pour développer ?']
        New_df.at[index, 'Notes'] = New_df.at[index, 'Notes'] + switch_example(valuer) 
load_df = load(targetfile ="transformdata1.csv", data_to_load=New_df)
#New_df['5. Quelle(s) matière(s) avez-vous aimé particulièrement au lycée parmi les suivantes : ']
New_df
# Out:
#           Horodateur 1. Quel est votre numéro étudiant ? (ex: e22XXXX)  \
# 0   10/11/2022 11:24                                           e201962
# 1   10/11/2022 11:25                                           E200293
# 2   10/11/2022 11:25                                          e2205472
# 3   10/11/2022 11:25                                          e2204879
# 4   10/11/2022 11:25                                          e2204699
# 5   10/11/2022 11:26                                          e2205039
# 6   10/11/2022 11:27                                          E2205565
# 7   10/11/2022 11:28                                          e2205559
# 8   10/11/2022 11:28                                          e2205212
# 9   10/11/2022 11:28                                           e201142
# 10  10/11/2022 11:28                                          E2204723
# 11  10/11/2022 11:28                                     E222120191817
# 12  10/11/2022 11:28                                          e2205343
# 13  10/11/2022 11:28                                         e22005023
# 14  10/11/2022 11:28                                          e2205261
# 15  10/11/2022 11:28                                           e201067
# 16  10/11/2022 11:28                                          e2205472
# 17  10/11/2022 11:29                                          e2206068
# 18  10/11/2022 11:29                                          e2205046
# 19  10/11/2022 11:29                                           E201931
# 20  10/11/2022 11:29                                          U2107800
# 21  10/11/2022 11:29                                          e2203685
# 22  10/11/2022 11:30                                           e200776
# 23  10/11/2022 11:30                                          e2205435
# 24  10/11/2022 11:30                                          e2205562
# 25  10/11/2022 11:30                                          e2205762
# 26  10/11/2022 11:31                                           e202211
# 27  10/11/2022 11:31                                          e2204707
# 28  10/11/2022 11:34                                          e2205363
# 29  10/11/2022 11:35                                           s206985
# 30  10/11/2022 11:39                                           e201116
# 31  10/11/2022 13:21                                          e2204701
# 32  10/11/2022 14:27                                          e2204767
# 33  10/11/2022 14:30                                           e200790
# 34  10/11/2022 17:35                                           e200942
#
#    2. Quelle est la définition d’un ingénieur qui vous correspond le mieux ?  \
# 0   C’est un professionnel expert dans un domaine ...
# 1   C’est un professionnel expert dans un domaine ...
# 2   C’est un professionnel expert dans un domaine ...
# 3   Un ingénieur est un Homme capable de prendre d...
# 4   Un ingénieur est un Homme capable de prendre d...
# 5   C’est un professionnel expert dans un domaine ...
# 6   C’est un professionnel expert dans un domaine ...
# 7   C’est un professionnel expert dans un domaine ...
# 8   C’est un professionnel expert dans un domaine ...
# 9   Un ingénieur est un Homme capable de prendre d...
# 10  C’est un professionnel expert dans un domaine ...
# 11  C’est avant tout un cadre supérieur technique ...
# 12  C’est un professionnel expert dans un domaine ...
# 13  C’est un professionnel expert dans un domaine ...
# 14  C’est avant tout un cadre supérieur technique ...
# 15  C’est avant tout un cadre supérieur technique ...
# 16  Un ingénieur est un Homme capable de prendre d...
# 17  C’est avant tout un cadre supérieur technique ...
# 18  C’est un professionnel expert dans un domaine ...
# 19  Un ingénieur est un Homme capable de prendre d...
# 20  C’est un professionnel expert dans un domaine ...
# 21  C’est un professionnel expert dans un domaine ...
# 22  C’est un professionnel expert dans un domaine ...
# 23  C’est un professionnel expert dans un domaine ...
# 24  C’est un professionnel expert dans un domaine ...
# 25  C’est avant tout un cadre supérieur technique ...
# 26  Un ingénieur est un Homme capable de prendre d...
# 27  C’est avant tout un cadre supérieur technique ...
# 28  C’est un professionnel expert dans un domaine ...
# 29  Un ingénieur est un Homme capable de prendre d...
# 30  C’est avant tout un cadre supérieur technique ...
# 31  Un ingénieur est un Homme capable de prendre d...
# 32  C’est avant tout un cadre supérieur technique ...
# 33  Un ingénieur est un Homme capable de prendre d...
# 34  Un ingénieur est un Homme capable de prendre d...
#
#     3. Êtes-vous plutôt programmation ... [Procédurale]  \
# 0                                                   2
# 1                                                   1
# 2                                                   2
# 3                                                   2
# 4                                                   3
# 5                                                   2
# 6                                                   3
# 7                                                   2
# 8                                                   1
# 9                                                   2
# 10                                                  1
# 11                                                  1
# 12                                                  2
# 13                                                  1
# 14                                                  2
# 15                                                  2
# 16                                                  2
# 17                                                  3
# 18                                                  1
# 19                                                  2
# 20                                                  1
# 21                                                  1
# 22                                                  2
# 23                                                  2
# 24                                                  1
# 25                                                  1
# 26                                                  3
# 27                                                  1
# 28                                                  1
# 29                                                  1
# 30                                                  1
# 31                                                  3
# 32                                                  2
# 33                                                  2
# 34                                                  3
#
#     3. Êtes-vous plutôt programmation ... [Orienté Object]  \
# 0                                                   2
# 1                                                   1
# 2                                                   3
# 3                                                   3
# 4                                                   3
# 5                                                   3
# 6                                                   2
# 7                                                   3
# 8                                                   2
# 9                                                   2
# 10                                                  3
# 11                                                  1
# 12                                                  1
# 13                                                  1
# 14                                                  3
# 15                                                  2
# 16                                                  3
# 17                                                  1
# 18                                                  3
# 19                                                  1
# 20                                                  3
# 21                                                  1
# 22                                                  2
# 23                                                  2
# 24                                                  1
# 25                                                  2
# 26                                                  2
# 27                                                  3
# 28                                                  1
# 29                                                  1
# 30                                                  2
# 31                                                  3
# 32                                                  2
# 33                                                  2
# 34                                                  2
#
#     3. Êtes-vous plutôt programmation ... [Fonctionnelle]  4.Web  4.Cloud  \
# 0                                                   2          1        1
# 1                                                   2          2        2
# 2                                                   2          3        2
# 3                                                   2          3        1
# 4                                                   1          0        0
# 5                                                   2          1        2
# 6                                                   3          3        2
# 7                                                   2          3        1
# 8                                                   3          2        1
# 9                                                   2          2        1
# 10                                                  2          2        0
# 11                                                  1          1        1
# 12                                                  3          2        2
# 13                                                  1          5        5
# 14                                                  1          1        0
# 15                                                  2          2        2
# 16                                                  2          5        2
# 17                                                  1          0        0
# 18                                                  2          3        3
# 19                                                  1          2        3
# 20                                                  2          5        3
# 21                                                  1          3        1
# 22                                                  2          0        1
# 23                                                  2          5        2
# 24                                                  1          3        3
# 25                                                  1          5        0
# 26                                                  1          1        0
# 27                                                  2          5        2
# 28                                                  1          5        0
# 29                                                  1          5        3
# 30                                                  2          2        1
# 31                                                  2          2        3
# 32                                                  3          3        1
# 33                                                  2          3        2
# 34                                                  1          3        0
#
#     4.Embarqué  4.Mobile  ...  \
# 0            5         2  ...
# 1            2         3  ...
# 2            2         3  ...
# 3            0         2  ...
# 4            5         0  ...
# 5            2         1  ...
# 6            3         3  ...
# 7            3         3  ...
# 8            3         3  ...
# 9            3         3  ...
# 10           1         2  ...
# 11           2         2  ...
# 12           0         2  ...
# 13           0         5  ...
# 14           1         2  ...
# 15           2         2  ...
# 16           2         5  ...
# 17           0         0  ...
# 18           2         3  ...
# 19           5         2  ...
# 20           2         5  ...
# 21           0         3  ...
# 22           5         2  ...
# 23           2         5  ...
# 24           5         5  ...
# 25           0         5  ...
# 26           1         2  ...
# 27           1         5  ...
# 28           1         3  ...
# 29           1         5  ...
# 30           1         2  ...
# 31           5         3  ...
# 32           2         3  ...
# 33           3         3  ...
# 34           0         2  ...
#
#     9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Ensim’elec]  \
# 0                                           Interessé
# 1                                           Interessé
# 2                                       Pas intéressé
# 3                                       Pas intéressé
# 4                                       Pas intéressé
# 5                                      Ne connais pas
# 6                                       Pas intéressé
# 7                                       Pas intéressé
# 8                                           Interessé
# 9                                           Interessé
# 10                                      Pas intéressé
# 11                                          Interessé
# 12                                     Ne connais pas
# 13                                     Ne connais pas
# 14                                      Pas intéressé
# 15                                      Pas intéressé
# 16                                      Pas intéressé
# 17                                                  0
# 18                                          Interessé
# 19                                      Pas intéressé
# 20                                          Interessé
# 21                                      Pas intéressé
# 22                                          Interessé
# 23                                     Ne connais pas
# 24                                          Interessé
# 25                                     Ne connais pas
# 26                                      Pas intéressé
# 27                                      Pas intéressé
# 28                                      Pas intéressé
# 29                                     Ne connais pas
# 30                                      Pas intéressé
# 31                                          Interessé
# 32                                          Interessé
# 33                                      Pas intéressé
# 34                                      Pas intéressé
#
#    9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [Enigma]  \
# 0                                       Pas intéressé
# 1                                            J'y suis
# 2                                       Pas intéressé
# 3                                           Interessé
# 4                                       Pas intéressé
# 5                                      Ne connais pas
# 6                                       Pas intéressé
# 7                                       Pas intéressé
# 8                                                   0
# 9                                       Pas intéressé
# 10                                      Pas intéressé
# 11                                                  0
# 12                                     Ne connais pas
# 13                                     Ne connais pas
# 14                                           J'y suis
# 15                                      Pas intéressé
# 16                                      Pas intéressé
# 17                                                  0
# 18                                          Interessé
# 19                                      Pas intéressé
# 20                                                  0
# 21                                      Pas intéressé
# 22                                          Interessé
# 23                                                  0
# 24                                                  0
# 25                                     Ne connais pas
# 26                                      Pas intéressé
# 27                                          Interessé
# 28                                      Pas intéressé
# 29                                     Ne connais pas
# 30                                           J'y suis
# 31                                           J'y suis
# 32                                      Pas intéressé
# 33                                      Pas intéressé
# 34                                      Pas intéressé
#
#    9. De quelles associations faites-vous partie ? Ou souhaitez-vous rejoindre? [L'Ensimien]  \
# 0                                       Pas intéressé
# 1                                       Pas intéressé
# 2                                       Pas intéressé
# 3                                       Pas intéressé
# 4                                       Pas intéressé
# 5                                      Ne connais pas
# 6                                       Pas intéressé
# 7                                       Pas intéressé
# 8                                                   0
# 9                                       Pas intéressé
# 10                                      Pas intéressé
# 11                                          Interessé
# 12                                     Ne connais pas
# 13                                      Pas intéressé
# 14                                      Pas intéressé
# 15                                      Pas intéressé
# 16                                      Pas intéressé
# 17                                          Interessé
# 18                                      Pas intéressé
# 19                                      Pas intéressé
# 20                                          Interessé
# 21                                           J'y suis
# 22                                      Pas intéressé
# 23                                     Ne connais pas
# 24                                                  0
# 25                                     Ne connais pas
# 26                                      Pas intéressé
# 27                                      Pas intéressé
# 28                                      Pas intéressé
# 29                                     Ne connais pas
# 30                                      Pas intéressé
# 31                                      Pas intéressé
# 32                                      Pas intéressé
# 33                                      Pas intéressé
# 34                                      Pas intéressé
#
#    10. Si on vous donne une imprimante 3D, qu'est-ce que vous imprimez d’abord ?  \
# 0                                     Statue de Mario
# 1                                     Statue de Mario
# 2                       Boitier pour sa carte arduino
# 3                                     Statue de Mario
# 4                                     Statue de Mario
# 5                              Une coque de téléphone
# 6                                     Statue de Mario
# 7                              Une coque de téléphone
# 8                       Boitier pour sa carte arduino
# 9                       Boitier pour sa carte arduino
# 10                                    Statue de Mario
# 11                             Une coque de téléphone
# 12                             Une coque de téléphone
# 13                             Une coque de téléphone
# 14                                    Statue de Mario
# 15                             Une coque de téléphone
# 16                      Boitier pour sa carte arduino
# 17                             Une coque de téléphone
# 18                                    Statue de Mario
# 19                      Boitier pour sa carte arduino
# 20                             Une coque de téléphone
# 21                             Une coque de téléphone
# 22                      Boitier pour sa carte arduino
# 23                             Une coque de téléphone
# 24                      Boitier pour sa carte arduino
# 25                             Une coque de téléphone
# 26                             Une coque de téléphone
# 27                                    Statue de Mario
# 28                             Une coque de téléphone
# 29                             Une coque de téléphone
# 30                                    Statue de Mario
# 31                      Boitier pour sa carte arduino
# 32                                        Des boutons
# 33                                    Statue de Mario
# 34                             Une coque de téléphone
#
#                          11. Quels sont vos hobbies ?  \
# 0      Lecture, Bricolage, Jeux vidéos, Programmation
# 1   Sport, Art Dessin, Jeux vidéos, Musique, Muscu...
# 2                         Jeux vidéos, Programmation
# 3   Lecture, Sport, Jeux vidéos, Musculation, Prog...
# 4                                         Jeux vidéos
# 5                                            Trading
# 6                                  Sport, Jeux vidéos
# 7                         Sport, Musique, Musculation
# 8                       Bricolage, Sport, Jeux vidéos
# 9                         Lecture, Bricolage, Musique
# 10                               Jeux vidéos, Musique
# 11                        Lecture, Bricolage, Musique
# 12               Lecture, Sport, Jeux vidéos, Musique
# 13                                            Lecture
# 14           Sport, Jeux vidéos, Musique, Musculation
# 15                                            Musique
# 16                        Jeux vidéos, programmation
# 17                                            Lecture
# 18                                        Jeux vidéos
# 19                              Automatiser ma maison
# 20           Sport, Jeux vidéos, Musique, Musculation
# 21               Lecture, Sport, Jeux vidéos, Musique
# 22                                        Jeux vidéos
# 23                                            Musique
# 24             Bricolage, Sport, Jeux vidéos, Musique
# 25                                            Musique
# 26                                              Sport
# 27                 Sport, Jeux vidéos, Programmation
# 28  Bricolage, Sport, Jeux vidéos, Musique, Muscul...
# 29                        Sport, Jeux vidéos, Musique
# 30  Lecture, Sport, Art Dessin, Jeux vidéos, Jeux ...
# 31           Lecture, Bricolage, Jeux vidéos, Musique
# 32                                              Sport
# 33  Lecture, Sport, Art Dessin, Jeux vidéos, Musiq...
# 34                                 Sport, Jeux vidéos
#
#    12. Utilisez-vous des sites pour créer une palette de couleurs ?  \
# 0                                                 Non
# 1                                                 Non
# 2                                                 Oui
# 3                                                 Oui
# 4                                                 Non
# 5                                                 Non
# 6                                                 Non
# 7                                                 Non
# 8                                                 Non
# 9                                                 Non
# 10                                                Non
# 11                                                Non
# 12                                                Non
# 13                                                Oui
# 14                                                Non
# 15                                                Non
# 16                                                  0
# 17                                                Non
# 18                                                Non
# 19                                                Non
# 20                                                Non
# 21                                                Non
# 22                                                Non
# 23                                                Non
# 24                                                Non
# 25                                                Non
# 26                                                Non
# 27                                                Oui
# 28                                                Oui
# 29                                                Non
# 30                                                Non
# 31                                                Oui
# 32                                                Non
# 33                                                Non
# 34                                                Non
#
#    13. Votre ordinateur tombe en panne, que faites vous ?  \
# 0   Vous essayez de le réparer en passant par le BIOS
# 1   Vous le démontez pour comprendre d'où vient le...
# 2   Vous le démontez pour comprendre d'où vient le...
# 3   Vous essayez de le réparer en passant par le BIOS
# 4                       Vous allez voir un réparateur
# 5   Vous essayez de le réparer en passant par le BIOS
# 6   Vous le démontez pour comprendre d'où vient le...
# 7   Vous essayez de le réparer en passant par le BIOS
# 8                       Vous allez voir un réparateur
# 9   Vous le démontez pour comprendre d'où vient le...
# 10  Vous le démontez pour comprendre d'où vient le...
# 11  Vous essayez de le réparer en passant par le BIOS
# 12                      Vous allez voir un réparateur
# 13  Vous essayez de le réparer en passant par le BIOS
# 14                      Vous allez voir un réparateur
# 15                      Vous allez voir un réparateur
# 16  Vous le démontez pour comprendre d'où vient le...
# 17                      Vous allez voir un réparateur
# 18  Vous essayez de le réparer en passant par le BIOS
# 19  Vous essayez de le réparer en passant par le BIOS
# 20  Vous essayez de le réparer en passant par le BIOS
# 21                      Vous allez voir un réparateur
# 22                      Vous allez voir un réparateur
# 23  Vous essayez de le réparer en passant par le BIOS
# 24  Vous le démontez pour comprendre d'où vient le...
# 25                      Vous allez voir un réparateur
# 26                      Vous allez voir un réparateur
# 27  Vous le démontez pour comprendre d'où vient le...
# 28  Vous essayez de le réparer en passant par le BIOS
# 29                      Vous allez voir un réparateur
# 30                      Vous allez voir un réparateur
# 31  Vous essayez de le réparer en passant par le BIOS
# 32                      Vous allez voir un réparateur
# 33                      Vous allez voir un réparateur
# 34                      Vous allez voir un réparateur
#
#    14. Qu’avez-vous fait avant le cycle ingénieur ?  \
# 0                                     Prépa intégré
# 1                                     Prépa intégré
# 2                                           BTS SIO
# 3                                            BTS SN
# 4                                  DUT Informatique
# 5                                    CPGE MP2I/MPSI
# 6                                           CPGE MP
# 7                                           CPGE MP
# 8                                           CPGE MP
# 9                                     Prépa intégré
# 10                                          BTS SIO
# 11                                                0
# 12                                          CPGE MP
# 13                                          BTS SIO
# 14                                          CPGE MP
# 15                                    Prépa intégré
# 16                                          BTS SIO
# 17                                    Prépa intégré
# 18                                          CPGE MP
# 19                                    Prépa intégré
# 20                                 DUT Informatique
# 21                                          CPGE BL
# 22                                    Prépa intégré
# 23                                          CPGE MP
# 24                                          CPGE MP
# 25                                                0
# 26                                    Prépa intégré
# 27                                           BTS SN
# 28                                                0
# 29                                          CPGE MP
# 30                                    Prépa intégré
# 31                                 DUT Informatique
# 32                                 DUT Informatique
# 33                                    Prépa intégré
# 34                                    Prépa intégré
#
#    15. Quel est ton système d’exploitation que tu utilises le plus pour développer ?  \
# 0                                             Windows
# 1                                             Windows
# 2        Distribution Linux (Ubuntu, Debian, Arch...)
# 3                                               MacOS
# 4        Distribution Linux (Ubuntu, Debian, Arch...)
# 5                                             Windows
# 6                                             Windows
# 7                                               MacOS
# 8                                             Windows
# 9                                             Windows
# 10                                            Windows
# 11       Distribution Linux (Ubuntu, Debian, Arch...)
# 12                                            Windows
# 13       Distribution Linux (Ubuntu, Debian, Arch...)
# 14                                            Windows
# 15                                            Windows
# 16       Distribution Linux (Ubuntu, Debian, Arch...)
# 17                                            Windows
# 18                                            Windows
# 19                                            Windows
# 20       Distribution Linux (Ubuntu, Debian, Arch...)
# 21                                            Windows
# 22                                            Windows
# 23                                            Windows
# 24                                            Windows
# 25                                            Windows
# 26                                            Windows
# 27                                            Windows
# 28                                            Windows
# 29                                            Windows
# 30                                            Windows
# 31       Distribution Linux (Ubuntu, Debian, Arch...)
# 32                                            Windows
# 33                                            Windows
# 34                                            Windows
#
#    Notes
# 0      0
# 1     -8
# 2     -9
# 3     -6
# 4     -1
# 5     12
# 6     -2
# 7      0
# 8     -2
# 9     -1
# 10   -10
# 11     7
# 12    -4
# 13    -7
# 14    -7
# 15    -9
# 16   -17
# 17   -10
# 18    -9
# 19     6
# 20   -10
# 21   -10
# 22     7
# 23   -13
# 24     3
# 25   -19
# 26    -4
# 27   -15
# 28    -6
# 29    -9
# 30    -7
# 31     0
# 32    -4
# 33    -9
# 34    -6
#
# [35 rows x 34 columns]

# %%
 for index, row in New_df.iterrows():
        print(New_df.at[index, '5. Quelle(s) matière(s) avez-vous aimé particulièrement au lycée parmi les suivantes : '].split(","))
# Out:
# ['Maths', ' Physique/Chimie', " Sciences de l'ingénieur"]
# ['Maths', ' Physique/Chimie', ' Littérature/Philosophie', ' Histoire/Géographie']
# ['Histoire/Géographie']
# ['Maths', ' Arts Plastiques/Arts appliqués', " Sciences de l'ingénieur"]
# ["Sciences de l'ingénieur"]
# ['Physique/Chimie', ' Littérature/Philosophie', ' Sciences de gestion', " Sciences de l'ingénieur"]
# ['Maths', ' Physique/Chimie', " Sciences de l'ingénieur"]
# ['Maths', " Sciences de l'ingénieur"]
# ['Maths', ' Physique/Chimie', " Sciences de l'ingénieur"]
# ['Maths', ' Physique/Chimie', ' Allemand']
# ['Maths', ' Physique/Chimie']
# ['Maths', ' Physique/Chimie', ' Histoire/Géographie', " Sciences de l'ingénieur"]
# ['Maths']
# ['Maths', " Sciences de l'ingénieur"]
# ['Maths', ' Littérature/Philosophie']
# ['Maths', ' Physique/Chimie']
# ['Histoire/Géographie']
# ['Littérature/Philosophie']
# ['Maths']
# ['Physique/Chimie', ' Littérature/Philosophie', " Sciences de l'ingénieur"]
# ['Maths', ' Sciences de gestion', " Sciences de l'ingénieur"]
# ['Maths', ' Littérature/Philosophie', ' Histoire/Géographie']
# ['Maths', ' Physique/Chimie', " Sciences de l'ingénieur"]
# ['Maths', ' Physique/Chimie', " Sciences de l'ingénieur"]
# ['Maths', ' Physique/Chimie', " Sciences de l'ingénieur"]
# ['Maths', ' Littérature/Philosophie', ' Histoire/Géographie']
# ['Maths', ' Sport']
# ['Maths', " Sciences de l'ingénieur"]
# ['Maths', ' Arts Plastiques/Arts appliqués', ' Électronique numérique ']
# ['Maths', ' Physique/Chimie', " Sciences de l'ingénieur", ' Sport']
# ['Maths', ' Physique/Chimie', ' Littérature/Philosophie', ' Histoire/Géographie', ' Arts Plastiques/Arts appliqués']
# ['Maths', ' Physique/Chimie', ' Littérature/Philosophie', ' Sciences de gestion', ' Informatique et science du numerique']
# ['Maths', ' Histoire/Géographie', ' Arts Plastiques/Arts appliqués', " Sciences de l'ingénieur"]
# ['Maths']
# ['Maths', ' Littérature/Philosophie', ' Histoire/Géographie', ' Informatique et Sciences du Numérique']
